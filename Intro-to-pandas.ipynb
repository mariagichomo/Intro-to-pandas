# %%
#Below is a dictionary
import pandas as pd
Products_Dict = {
    "Customer_id" : [1,2,3,4],
    "Product" :['Oven', 'Jiko', 'Television', 'Headphones'],
    "Price" :[20000,2500,54000,3200]
}
Products_Dict
# Out:
# {'Customer_id': [1, 2, 3, 4],
#  'Product': ['Oven', 'Jiko', 'Television', 'Headphones'],
#  'Price': [20000, 2500, 54000, 3200]}

# %%
#To create a dataframe from the dictionary :
#import the pandas package
#Use the pandas Dataframe() function to convert the dictionary to a dataframe
import pandas as pd
DataFrame1 = pd.DataFrame(Products_Dict)
DataFrame1
# Out:
#    Customer_id     Product  Price
# 0            1        Oven  20000
# 1            2        Jiko   2500
# 2            3  Television  54000
# 3            4  Headphones   3200

# %%
#My first trial of converting a dictionary to a dataframe
import pandas as pd
Cars_Dict ={
    "Country_names" : ['United States','Australia','Japan','India','Russia','Morocco','Egypt'],
    "drives_right" : [True,False,False,False,True,True,True],
    "Cars_per_cap" : [809,731,588,18,200,70,45]
}
Cars_Dict
# Out:
# {'Country_names': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True],
#  'Cars_per_cap': [809, 731, 588, 18, 200, 70, 45]}

# %%
import pandas as pd
DataFrame1 = pd.DataFrame(Cars_Dict)
DataFrame1
# Out:
#    Country_names  drives_right  Cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
#Creating a dataframe by importing a .csv or a .json etc
import pandas as pd
titanic_df = pd.read_csv('titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
titanic_df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 398         1290         0       3
# 399         1291         0       3
# 400         1292         1       1
# 401         1293         0       2
# 402         1294         1       1
# 403         1295         0       1
# 404         1296         0       1
# 405         1297         0       2
# 406         1298         0       2
# 407         1299         0       1
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 398                   Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic_df.describe(include=['object'])
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
titanic_df.shape
# Out:
# (418, 12)

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df.rename(columns={
    'Sex': 'Gender',
    'Pclass': 'PassengerClass'
  }, inplace=True)
#

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'PassengerClass', 'Name', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#To create a new column, say Age squared
titanic_df['Age_Squared'] = titanic_df['Age']**2
titanic_df
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0            892         0               3
# 1            893         1               3
# 2            894         0               2
# 3            895         0               3
# 4            896         1               3
# ..           ...       ...             ...
# 413         1305         0               3
# 414         1306         1               1
# 415         1307         0               3
# 416         1308         0               3
# 417         1309         0               3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %%
#Column access with square brackets
titanic_df[['Gender']]
# Out:
#      Gender
# 0      male
# 1    female
# 2      male
# 3      male
# 4    female
# ..      ...
# 413    male
# 414  female
# 415    male
# 416    male
# 417    male
#
# [418 rows x 1 columns]

# %%
#To select more than one column
titanic_df[['Survived','Name']]
# Out:
#      Survived                                          Name
# 0           0                              Kelly, Mr. James
# 1           1              Wilkes, Mrs. James (Ellen Needs)
# 2           0                     Myles, Mr. Thomas Francis
# 3           0                              Wirz, Mr. Albert
# 4           1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..        ...                                           ...
# 413         0                            Spector, Mr. Woolf
# 414         1                  Oliva y Ocana, Dona. Fermina
# 415         0                  Saether, Mr. Simon Sivertsen
# 416         0                           Ware, Mr. Frederick
# 417         0                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
#median age of dataset
titanic_df['Age'].median()
# Out:
# 27.0

# %%
#minimum age in the dataset
titanic_df['Age'].min()
# Out:
# 0.17

# %%
#maximum age in the dataset
titanic_df['Age'].max()
# Out:
# 76.0

# %%
#Row Access with square brackets
titanic_df[0:31]
# Out:
#     PassengerId  Survived  PassengerClass  \
# 0           892         0               3
# 1           893         1               3
# 2           894         0               2
# 3           895         0               3
# 4           896         1               3
# 5           897         0               3
# 6           898         1               3
# 7           899         0               2
# 8           900         1               3
# 9           901         0               3
# 10          902         0               3
# 11          903         0               1
# 12          904         1               1
# 13          905         0               2
# 14          906         1               1
# 15          907         1               2
# 16          908         0               2
# 17          909         0               3
# 18          910         1               3
# 19          911         1               3
# 20          912         0               1
# ...

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0          892         0               3
# 1          893         1               3
# 2          894         0               2
# 3          895         0               3
# 4          896         1               3
# 5          897         0               3
# 6          898         1               3
# 7          899         0               2
# 8          900         1               3
# 9          901         0               3
#
#                                            Name  Gender   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_df.loc[[5,7,15]]
# Out:
#     PassengerId  Survived  PassengerClass  \
# 5           897         0               3
# 7           899         0               2
# 15          907         1               2
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1      0
#
#            Ticket     Fare Cabin Embarked  Age_Squared
# 5            7538   9.2250   NaN        S        196.0
# 7          248738  29.0000   NaN        S        676.0
# 15  SC/PARIS 2167  27.7208   NaN        C        576.0

# %%
titanic_df.iloc[[5,7,15]]
# Out:
#     PassengerId  Survived  PassengerClass  \
# 5           897         0               3
# 7           899         0               2
# 15          907         1               2
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1      0
#
#            Ticket     Fare Cabin Embarked  Age_Squared
# 5            7538   9.2250   NaN        S        196.0
# 7          248738  29.0000   NaN        S        676.0
# 15  SC/PARIS 2167  27.7208   NaN        C        576.0

# %%
#Row and colum access with loc
titanic_df.loc[[0,5,79,45],"Survived":"Age"]
# Out:
#     Survived  PassengerClass                             Name  Gender   Age
# 0          0               3                 Kelly, Mr. James    male  34.5
# 5          0               3       Svensson, Mr. Johan Cervin    male  14.0
# 79         1               3           Doyle, Miss. Elizabeth  female  24.0
# 45         0               3  Peltomaki, Mr. Nikolai Johannes    male  25.0

# %%
#Row and column access with iloc
titanic_df.iloc[[0,5,79,45],[1,5]]
# Out:
#     Survived   Age
# 0          0  34.5
# 5          0  14.0
# 79         1  24.0
# 45         0  25.0

# %%
titanic_df['Gender'].unique()
#titanic_df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_df[titanic_df['Gender']=='female']
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1            893         1               3
# 4            896         1               3
# 6            898         1               3
# 8            900         1               3
# 12           904         1               1
# ..           ...       ...             ...
# 409         1301         1               3
# 410         1302         1               3
# 411         1303         1               1
# 412         1304         1               3
# 414         1306         1               1
#
#                                                 Name  Gender   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# ...

# %%
titanic_df['Name'].unique()
# Out:
# array(['Kelly, Mr. James', 'Wilkes, Mrs. James (Ellen Needs)',
#        'Myles, Mr. Thomas Francis', 'Wirz, Mr. Albert',
#        'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#        'Svensson, Mr. Johan Cervin', 'Connolly, Miss. Kate',
#        'Caldwell, Mr. Albert Francis',
#        'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#        'Davies, Mr. John Samuel', 'Ilieff, Mr. Ylio',
#        'Jones, Mr. Charles Cresson',
#        'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#        'Howard, Mr. Benjamin',
#        'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#        'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#        'Keane, Mr. Daniel', 'Assaf, Mr. Gerios',
#        'Ilmakangas, Miss. Ida Livija',
#        'Assaf Khalil, Mrs. Mariana (Miriam")"', 'Rothschild, Mr. Martin',
#        'Olsen, Master. Artur Karl',
#        'Flegenheim, Mrs. Alfred (Antoinette)',
#        'Williams, Mr. Richard Norris II',
# ...

# %%
titanic_df[(titanic_df['Name']==Miss.Kate)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 titanic_df[(titanic_df['Name']==Miss. Kate)]
#
# NameError: name 'Miss' is not defined

# %%
titanic_df['Age'].unique
# Out:
# <bound method Series.unique of 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64>

# %%
#Dataframe with people above 40 years
titanic_df[(titanic_df['Age']>40)]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1            893         1               3
# 2            894         0               2
# 11           903         0               1
# 13           905         0               2
# 14           906         1               1
# ..           ...       ...             ...
# 391         1283         1               1
# 393         1285         0               2
# 397         1289         1               1
# 404         1296         0               1
# 407         1299         0               1
#
#                                                   Name  Gender   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# ...

# %%
titanic_df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
titanic_df[(titanic_df['Survived']==1)]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1            893         1               3
# 4            896         1               3
# 6            898         1               3
# 8            900         1               3
# 12           904         1               1
# ..           ...       ...             ...
# 409         1301         1               3
# 410         1302         1               3
# 411         1303         1               1
# 412         1304         1               3
# 414         1306         1               1
#
#                                                 Name  Gender   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# ...

# %%
#return a dataframe with only passengers below 40 or above 30
titanic_df[(titanic_df['Age']>=30) & (titanic_df['Age']<=40)]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0            892         0               3
# 6            898         1               3
# 16           908         0               2
# 32           924         1               3
# 34           926         0               1
# ..           ...       ...             ...
# 400         1292         1               1
# 401         1293         0               2
# 411         1303         1               1
# 414         1306         1               1
# 415         1307         0               3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 6                               Connolly, Miss. Kate  female  30.0      0
# 16                                 Keane, Mr. Daniel    male  35.0      0
# 32          Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0      1
# ...

# %%
titanic_df[(titanic_df['Survived']==0)]
# Out:
#      PassengerId  Survived  PassengerClass                          Name  \
# 0            892         0               3              Kelly, Mr. James
# 2            894         0               2     Myles, Mr. Thomas Francis
# 3            895         0               3              Wirz, Mr. Albert
# 5            897         0               3    Svensson, Mr. Johan Cervin
# 7            899         0               2  Caldwell, Mr. Albert Francis
# ..           ...       ...             ...                           ...
# 407         1299         0               1    Widener, Mr. George Dunton
# 413         1305         0               3            Spector, Mr. Woolf
# 415         1307         0               3  Saether, Mr. Simon Sivertsen
# 416         1308         0               3           Ware, Mr. Frederick
# 417         1309         0               3      Peter, Master. Michael J
#
#     Gender   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
titanic_df.groupby('Gender')[['Age']].mean()
# Out:
#               Age
# Gender
# female  30.272362
# male    30.272732

# %%
#To sort using a column of your choice
#Lets use Age
titanic_df.sort_values(by=['Age'])
# Out:
#      PassengerId  Survived  PassengerClass  \
# 354         1246         1               3
# 201         1093         0               3
# 281         1173         0               3
# 307         1199         0               3
# 250         1142         1               2
# ..           ...       ...             ...
# 408         1300         1               3
# 410         1302         1               3
# 413         1305         0               3
# 416         1308         0               3
# 417         1309         0               3
#
#                                         Name  Gender   Age  SibSp  Parch  \
# 354  Dean, Miss. Elizabeth Gladys Millvina""  female  0.17      1      2
# 201  Danbom, Master. Gilbert Sigvard Emanuel    male  0.33      0      2
# 281           Peacock, Master. Alfred Edward    male  0.75      1      1
# 307                Aks, Master. Philip Frank    male  0.83      0      1
# 250                    West, Miss. Barbara J  female  0.92      1      2
# ...

# %%
titanic_df.sort_values(by=['Name'],ascending=False)
# Out:
#      PassengerId  Survived  PassengerClass  \
# 192         1084         0               3
# 344         1236         0               3
# 15           907         1               2
# 260         1152         0               3
# 336         1228         0               2
# ..           ...       ...             ...
# 8            900         1               3
# 251         1143         0               3
# 57           949         0               3
# 345         1237         1               3
# 392         1284         0               3
#
#                                               Name  Gender   Age  SibSp  \
# 192              van Billiard, Master. Walter John    male  11.5      1
# 344            van Billiard, Master. James William    male   NaN      1
# 15   del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 260           de Messemaeker, Mr. Guillaume Joseph    male  36.5      1
# 336                     de Brito, Mr. Jose Joaquim    male  32.0      0
# ...

# %%
#Returns true if the column has at least 1 missing value
titanic_df.isnull().any()
# Out:
# PassengerId       False
# Survived          False
# PassengerClass    False
# Name              False
# Gender            False
# Age                True
# SibSp             False
# Parch             False
# Ticket            False
# Fare               True
# Cabin              True
# Embarked          False
# Age_Squared        True
# dtype: bool

# %%
#Returns True if the whole column is null
titanic_df.isnull().all()
# Out:
# PassengerId       False
# Survived          False
# PassengerClass    False
# Name              False
# Gender            False
# Age               False
# SibSp             False
# Parch             False
# Ticket            False
# Fare              False
# Cabin             False
# Embarked          False
# Age_Squared       False
# dtype: bool

# %%
#Returns total number of missing values in a column
titanic_df.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# PassengerClass      0
# Name                0
# Gender              0
# Age                86
# SibSp               0
# Parch               0
# Ticket              0
# Fare                1
# Cabin             327
# Embarked            0
# Age_Squared        86
# dtype: int64

# %%
#imputing missing values with mean
Age = titanic_df['Age']
Age_mean = Age.mean()
print(Age_mean)
Age.fillna(Age_mean, inplace = True)
# Out:
# 30.272590361445783

# %%
#dropping any missing values
titanic_missing = titanic_df.dropna(axis = 1)
titanic_missing.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# PassengerClass    0
# Name              0
# Gender            0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Embarked          0
# dtype: int64
